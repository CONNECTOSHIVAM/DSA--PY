# %% [markdown]
# Tuple

# %%
# Q1. Create a tuple with the first 10 positive integers. Print the tuple.

tup = ()
for i in range(1,11):
    tup.

# %%
li = ['a', 'b', 'c'] * -3
print(li)
# Out:
# []

# %%
a = [10, 20, 30, 40, 50] 
b = [1, 2, 3, 4, 5] 


subtracted = list()
for a, b in zip(a, b):
    print(a,b)
    item = a -b
    subtracted.append(item)

print(subtracted)
# Out:
# 10 1
# 20 2
# 30 3
# 40 4
# 50 5
# [9, 18, 27, 36, 45]
